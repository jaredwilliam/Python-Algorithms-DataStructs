# %% [markdown]
# # Introduction
# We are going to go over some items to see how everything we have learned can connect to each other.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Displaying Information

# %%
def display(row1, row2, row3):
    print(row1)
    print(row2)
    print(row3)

# %%
row1 = [' ',' ',' ']
row2 = [' ',' ',' ']
row3 = [' ',' ',' ']

display(row1, row2, row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
row2[1] = 'X'

# %%
display(row1, row2, row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %% [markdown]
# # Accepting User Input

# %%
input('Please enter a value: ')
# Out:
# Please enter a value: 2
# '2'

# %%
result = input('Please enter a value: ')
# Out:
# Please enter a value: 2

# %%
result
# Out:
# '2'

# %% [markdown]
# Notice that the input function returns a string, so you may need to change the type to use it in the rest of the program.

# %% [markdown]
# # Validating User Input

# %%
def user_choice():
    choice = input("Please enter a number (0-10): ")
    
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10): 9
# 9

# %% [markdown]
# There are two problems with this. The user can pass in something that cannot be turned into an integer, such as 'nine', and the code still works even if the user provides a number outside the range, such as 100.

# %%
def user_choice():
    
    choice = 'WRONG'
    
    while choice.isdigit() == False: 
        choice = input("Please enter a number (0-10): ")
        if choice.isdigit() == False:
            print('Sorry that is not a digit!')
    
    
    return int(choice)

# %%
some_value = '100'
some_value.isdigit() # This means it can be turned into an integer
# Out:
# True

# %%
user_choice()
# Out:
# Please enter a number (0-10): asdfs
# Sorry that is not a digit!
# Please enter a number (0-10): 0
# 0

# %%
result = 'WRONG VALUE'

# %%
acceptable_values = [0,1,2]

# %%
result in acceptable_values
# Out:
# False

# %%
result not in acceptable_values
# Out:
# True

# %%
def user_choice():
    
    # Intial
    choice = 'WRONG'
    acceptable_range = range(0,10)
    within_range = False
    
    # two conditions to check
    # Is the user choice a digit?
    # Is it within range?
    
    while (choice.isdigit() == False) or (within_range == False): 
        
        choice = input("Please enter a number (0-10): ")
        
        # Digit check
        if choice.isdigit() == False:
            print('Sorry that is not a digit!')
        
        # Range check
        if choice.isdigit() == True:
            if int(choice) in acceptable_range:
                within_range = True
            else:
                print('Sorry, you are out of the acceptable range.')
                within_range = False
                
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10): two
# Sorry that is not a digit!
# Please enter a number (0-10): 100
# Sorry, you are out of the acceptable range.
# Please enter a number (0-10): 5
# 5

# %% [markdown]
# # Simple User Interaction
